# %% [markdown]
# ## Pandas is powerful library used for data manupulating widly used for data analytic

# %% [markdown]
# ## Series

# %%
import pandas as pd

# only performs columns 
data = [1,2,3,4,5]
series =pd.Series(data)
print(series)

dic = {"one":1 , "two":2 , "three" :3}
print(pd.Series(dic))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# one      1
# two      2
# three    3
# dtype: int64

# %% [markdown]
# ## Data Frames

# %%
# performs rows and columns
data ={
    "name":["ram" ,"thiru", 'gowri'],
    "age":[17,30,20],
    "voted":[1,2,3]
}
print(pd.DataFrame(data))
# Out:
#     name  age  voted
# 0    ram   17      1
# 1  thiru   30      2
# 2  gowri   20      3

# %% [markdown]
# ## Data manupulation:

# %% [markdown]
# ## reading various source Using pandas

# %%
# using to load the data in diffrent files and manupulate to it

# convertion of json -> data format

import pandas as pd
import json

data1 = '[{"name":"sathish","email":"sathish@gmail.com","roll":"ML"}]'

data = json.loads(data1)
df = pd.DataFrame(data)

df
# Out:
#       name              email roll
# 0  sathish  sathish@gmail.com   ML

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %% [markdown]
# ## xlsFile

# %%
df1=pd.read_excel("Sathish_LinkedIn_Job_Matches_Bangalore.xlsx")
df1
# Out:
#    Sathish Kumar S — LinkedIn Job Match Report | Bangalore | May 28, 2026  \
# 0   Resume: Java | Spring Boot | MySQL | REST APIs...
# 1                                                 NaN
# 2                                                   #
# 3                                                   1
# 4                                                   2
# 5                                                   3
# 6                                                   4
# 7                                                   5
# 8                                                   6
# 9                                                   7
# 10                                                  8
# 11                                                  9
# 12                                                 10
#
#                                   Unnamed: 1          Unnamed: 2  \
# 0                                        NaN                 NaN
# ...

# %% [markdown]
# ## pickle Format

# %%
#code can taken in production using pickle format

#convert xls file to pickle file 

df.to_pickle("data_pickle")  # already created file can convert pickle file 

df2 =pd.read_pickle("data_pickle") #read that pickle file it show pickle file
df2
# Out:
#       name              email roll
# 0  sathish  sathish@gmail.com   ML
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#age =[20,46,45,23,33]
age=["goms" , "siva" , "ram"]
ser=pd.Series(age,index = [99,98,97]) #modify the indexes
print(ser)
print(ser.loc[98]) #used for acess the value using indexes
print(ser.iloc[2])
# Out:
# 99    goms
# 98    siva
# 97     ram
# dtype: str
# siva
# ram

# %% [markdown]
# ## Dictionary format

# %%
age={
    "goms":12,
    "shiva":45,
    "thiru":33
}
s=pd.Series(age)
print(s[s>20])
# Out:
# shiva    45
# thiru    33
# dtype: int64

# %% [markdown]
# ## Data Frame

# %%
#create a dictnory it can contains set of series
students ={
    "name":["goms","shiva","rani"],
    "rollno":[1,2,3],
    "cgpa":[8.4,7.6,6.6]
}
#print(pd.DataFrame(students))

df=pd.DataFrame(students,index=[44,45,46])


# try to fix the new data frame column
df["medium"]=["english"," english","tamil"]


#try to fix neww data frame row

std=pd.DataFrame({"name":"raja","rollno":4,"cgpa":7.7 , "medium":"tamil"} , index=[47])
df =pd.concat([df,std])
print(df)
# Out:
#      name  rollno  cgpa    medium
# 44   goms       1   8.4   english
# 45  shiva       2   7.6   english
# 46   rani       3   6.6     tamil
# 47   raja       4   7.7     tamil

# %% [markdown]
# ## Import Files

# %%
import pandas as pd
df = pd.read_excel("Sathish_LinkedIn_Job_Matches_Bangalore.xlsx")
#print(df.head()) #df.head() using 1sr=t 5 coustomer datails show
print(df.to_string())
# Out:
#        #                                 Job Title             Company           Location (Bangalore) Location (Bangalore).1              Location (Bangalore).2  Location (Bangalore).3 Location (Bangalore).4                                             Location (Bangalore).5                     Location (Bangalore).6 Location (Bangalore).7                                                           Location (Bangalore).8 Location (Bangalore).9 Location (Bangalore).10
# 0    NaN                                       NaN                 NaN                            NaN                    NaN                                 NaN                     NaN                    NaN                                                                NaN                                        NaN                    NaN                                                                              NaN                    NaN                     NaN
# ...

# %% [markdown]
# ## Selection

# %%
print(df[['Job Title','Company','#']].to_string())  # select specific column
# Out:
#                                    Job Title             Company     #
# 0                                        NaN                 NaN   NaN
# 1                      Junior Java Developer              triSys   1.0
# 2         Associate Software Engineer - Java             Infosys   2.0
# 3   Software Engineer Trainee - Java Backend               Wipro   3.0
# 4                     Java Developer Fresher            HireWand   4.0
# 5   Software Engineer - Full Stack (Java+JS)         LTIMindtree   5.0
# 6            Junior Backend Developer - Java           Capgemini   6.0
# 7          Graduate Trainee - Java Developer           Cognizant   7.0
# 8        Java Backend Engineer (Entry Level)   Startup / Fintech   8.0
# 9            Software Developer - Java + Web       Tech Mahindra   9.0
# 10     Junior Full Stack Developer (Java/JS)  Persistent Systems  10.0

# %%
#specific row
#print(df.loc[1])
df = pd.read_excel("Sathish_LinkedIn_Job_Matches_Bangalore.xlsx" ,index_col="#")
df.to_string()
#print(df.loc[6.0,["Job Title" , "Company"]])  #specific column of specific rows
#print(df.loc[6.0 : 10.0,["Job Title" , "Company"]])  # ranges
print(df.iloc[0:5:1 , 1:3])  #rows , columns ,steps
# Out:
#       Company         Location (Bangalore)
# #
# NaN       NaN                          NaN
# 1.0    triSys      Bengaluru (Koramangala)
# 2.0   Infosys  Bengaluru (Electronic City)
# 3.0     Wipro    Bengaluru (Sarjapur Road)
# 4.0  HireWand      Bengaluru (Indiranagar)

# %% [markdown]
# ## Filtering

# %%
#filtered = df[df['Location (Bangalore).3']>=80.0]  #single conndition
filtered = df[(df['Location (Bangalore).4']=="Strong") & (df['Location (Bangalore).3']>=80.0)] # multiple condition also satisified

print(filtered.to_string())
# Out:
#                                     Job Title      Company           Location (Bangalore) Location (Bangalore).1 Location (Bangalore).2  Location (Bangalore).3 Location (Bangalore).4                                             Location (Bangalore).5            Location (Bangalore).6 Location (Bangalore).7                              Location (Bangalore).8 Location (Bangalore).9 Location (Bangalore).10
# #
# 5.0  Software Engineer - Full Stack (Java+JS)  LTIMindtree         Bengaluru (Whitefield)                On-site              0-2 years                    82.0                 Strong  Java, JavaScript, HTML5, CSS3, MySQL, REST APIs, Spring Boot, Git   React.js, Microservices, Docker                3.5-6.0  https://www.linkedin.com/company/ltimindtree/jobs/                  Today      Highly Recommended
# ...

# %% [markdown]
# ## Aggregate function

# %%
df = pd.read_excel("Sathish_LinkedIn_Job_Matches_Bangalore.xlsx" ,index_col="#")
df.to_string()
print(df.mean(numeric_only=True))
print(df.max(numeric_only=True))
print(df.sum(numeric_only=True))
print(df.count(numeric_only=True))
print(df.min(numeric_only=True))
print(df.median(numeric_only=True))
#print(df.mode(numeric_only=True))
# Out:
# Location (Bangalore).3    81.4
# dtype: float64
# Location (Bangalore).3    92.0
# dtype: float64
# Location (Bangalore).3    814.0
# dtype: float64
# Location (Bangalore).3    10
# dtype: int64
# Location (Bangalore).3    71.0
# dtype: float64
# Location (Bangalore).3    81.0
# dtype: float64

# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd
df=pd.read_excel("Sathish_LinkedIn_Job_Matches_Bangalore.xlsx" , index_col="#")
df=df.drop(columns=["Job Title"])  # drop the column
print(df.to_string()) 
# df.dropna()
#df.fillna()
#df["verity"]=df["verity"].replace()
#df["verity"]=df["veritey"].str.lower()
#df["verity"]=df["verity"].astype(np.int64)
#df=df.drop_duplicates()
# Out:
#                  Company           Location (Bangalore) Location (Bangalore).1              Location (Bangalore).2  Location (Bangalore).3 Location (Bangalore).4                                             Location (Bangalore).5                     Location (Bangalore).6 Location (Bangalore).7                                                           Location (Bangalore).8 Location (Bangalore).9 Location (Bangalore).10
# #
# NaN                  NaN                            NaN                    NaN                                 NaN                     NaN                    NaN                                                                NaN                                        NaN                    NaN                                                                              NaN                    NaN                     NaN
# ...
